# %%
import pandas as pd
original_df = pd.read_csv('anime.csv')
original_df.head(5)
# Out:
#                                         title episodes           status  \
# 0            Fullmetal Alchemist: Brotherhood       64  Finished Airing
# 1                                 Steins;Gate       24  Finished Airing
# 2                   Bleach: Sennen Kessen-hen       13  Finished Airing
# 3                                    Gintama°       51  Finished Airing
# 4  Kaguya-sama wa Kokurasetai: Ultra Romantic       13  Finished Airing
#
#       theme demographic                           genres type favorites  \
# 0  Military     Shounen  Action,Adventure,Drama,Fantasy,   TV   218,277
# 1   Unknown     Unknown           Drama,Sci-Fi,Suspense,   TV   183,596
# 2   Unknown     Shounen        Action,Adventure,Fantasy,   TV    18,421
# 3   Unknown     Shounen            Action,Comedy,Sci-Fi,   TV    16,042
# 4    School      Seinen                  Comedy,Romance,   TV    29,397
#
#   popularity rank  score    members  \
# 0         #3   #1   9.10  3,190,961
# 1        #13   #2   9.07  2,452,142
# 2       #458   #3   9.06    455,428
# 3       #332   #4   9.06    599,235
# 4       #193   #5   9.05    832,346
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Eccentric scientist Rintarou Okabe has a never...
# 2  Substitute Soul Reaper Ichigo Kurosaki spends ...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  The elite members of Shuchiin Academy's studen...
#
#                           aired         duration    premiered  \
# 0    Apr 5, 2009 to Jul 4, 2010  24 min. per ep.  Spring 2009
# 1   Apr 6, 2011 to Sep 14, 2011  24 min. per ep.  Spring 2011
# 2  Oct 11, 2022 to Dec 27, 2022  24 min. per ep.    Fall 2022
# 3   Apr 8, 2015 to Mar 30, 2016  24 min. per ep.  Spring 2015
# 4   Apr 9, 2022 to Jun 25, 2022  23 min. per ep.  Spring 2022
#
#                  studios
# 0                  Bones
# 1              White Fox
# 2                Pierrot
# 3  Bandai Namco Pictures
# 4           A-1 Pictures

# %%
anime=original_df.copy()

# %%
columns_to_drop = ['episodes', 'status', 'rank','aired','duration','premiered']
anime.drop(columns=columns_to_drop, inplace=True)

# %%
def remove_spaces(input_string):
    single_word = "".join(input_string.split())
    return single_word

# %%
title=anime['title'].apply(remove_spaces)

anime['theme']=anime['theme'].apply(remove_spaces)

anime['studios']=anime['studios'].apply(remove_spaces)

# %%
def remove_commas_add_spaces(text):
    return text.replace(',', ' ')

# %%
anime['genres']=anime['genres'].apply(remove_commas_add_spaces)

# %%
anime.head(10)
# Out:
#                                                title     theme demographic  \
# 0                   Fullmetal Alchemist: Brotherhood  Military     Shounen
# 1                                        Steins;Gate   Unknown     Unknown
# 2                          Bleach: Sennen Kessen-hen   Unknown     Shounen
# 3                                           Gintama°   Unknown     Shounen
# 4         Kaguya-sama wa Kokurasetai: Ultra Romantic    School      Seinen
# 5                 Shingeki no Kyojin Season 3 Part 2   Unknown     Shounen
# 6  Shingeki no Kyojin: The Final Season - Kankets...   Unknown     Shounen
# 7                                           Gintama'   Unknown     Shounen
# 8                                 Gintama: The Final   Unknown     Shounen
# 9                             Hunter x Hunter (2011)   Unknown     Shounen
#
#                             genres     type favorites popularity  score  \
# 0  Action Adventure Drama Fantasy        TV   218,277         #3   9.10
# 1           Drama Sci-Fi Suspense        TV   183,596        #13   9.07
# 2        Action Adventure Fantasy        TV    18,421       #458   9.06
# 3            Action Comedy Sci-Fi        TV    16,042       #332   9.06
# 4                  Comedy Romance        TV    29,397       #193   9.05
# 5                    Action Drama        TV    55,387        #24   9.05
# 6           Action Drama Suspense   Special     9,351       #465   9.04
# 7            Action Comedy Sci-Fi        TV     7,801       #387   9.04
# 8      Action Comedy Drama Sci-Fi     Movie     4,070      #1563   9.04
# 9        Action Adventure Fantasy        TV   201,103        #10   9.04
#
#      members                                           synopsis  \
# 0  3,190,961  After a horrific alchemy experiment goes wrong...
# 1  2,452,142  Eccentric scientist Rintarou Okabe has a never...
# 2    455,428  Substitute Soul Reaper Ichigo Kurosaki spends ...
# 3    599,235  Gintoki, Shinpachi, and Kagura return as the f...
# 4    832,346  The elite members of Shuchiin Academy's studen...
# 5  2,118,221  Seeking to restore humanity's diminishing hope...
# 6    449,149  In the wake of Eren Yeager's cataclysmic actio...
# 7    528,650  After a one-year hiatus, Shinpachi Shimura ret...
# 8    134,460  Two years have passed following the Tendoshuu'...
# 9  2,672,011  Hunters devote themselves to accomplishing haz...
#
#                studios
# 0                Bones
# 1             WhiteFox
# 2              Pierrot
# 3  BandaiNamcoPictures
# 4          A-1Pictures
# 5            WitStudio
# 6                MAPPA
# 7              Sunrise
# 8  BandaiNamcoPictures
# 9             Madhouse

# %%
def remove_words(text, words_to_remove):
    for word in words_to_remove:
        text = text.replace(word, '')
    return text

words_to_remove = ['\n\r\n[Written by MAL Rewrite]','\n\r\n']

anime['synopsis'] = anime['synopsis'].apply(lambda x: remove_words(x, words_to_remove))

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
def preprocess_text(text):
    text = text.lower()
    
    tokens = word_tokenize(text)
    
    tokens = [re.sub(r'[^a-zA-Z\s]', '', token) for token in tokens]
    
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# %%
anime['synopsis'] = anime['synopsis'].apply(preprocess_text)

# %%
anime['tags']=title+" "+anime['theme']+" "+anime['demographic']+" "+anime['genres']+" "+anime['type']+" "+anime['synopsis']+" "+anime['studios']

# %%
anime['tags'][1]
# Out:
# 'Steins;Gate Unknown Unknown Drama Sci-Fi Suspense  TV eccentric scientist rintarou okabe neverending thirst scientific exploration  together ditzy wellmeaning friend mayuri shiina roommate itaru hashida  rintarou found future gadget laboratory hope creating technological innovation baffle human psyche  despite claim grandeur  notable  gadget  trio created microwave mystifying power turn banana green goohowever  rintarou decides attend neuroscientist kurisu makise conference time travel  experience series strange event lead believe  phone microwave  gadget meet eye  apparently able send text message past using microwave  rintarou dabbles  time machine   attracting ire attention mysterious organization serndue novel discovery  rintarou friend find everpresent danger  work mitigate damage invention caused timeline  fighting battle save loved one  also one degrading sanity  WhiteFox'

# %%
anime['tags'] = anime['tags'].apply(lambda x:x.replace('Unknown ', ''))
#remove double space
anime['tags'] = anime['tags'].apply(lambda x: ' '.join(x.split()))

# %%
anime['tags'][1]
# Out:
# 'Steins;Gate Drama Sci-Fi Suspense TV eccentric scientist rintarou okabe neverending thirst scientific exploration together ditzy wellmeaning friend mayuri shiina roommate itaru hashida rintarou found future gadget laboratory hope creating technological innovation baffle human psyche despite claim grandeur notable gadget trio created microwave mystifying power turn banana green goohowever rintarou decides attend neuroscientist kurisu makise conference time travel experience series strange event lead believe phone microwave gadget meet eye apparently able send text message past using microwave rintarou dabbles time machine attracting ire attention mysterious organization serndue novel discovery rintarou friend find everpresent danger work mitigate damage invention caused timeline fighting battle save loved one also one degrading sanity WhiteFox'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(max_features=10000,ngram_range=(1,2))

# %%
vector = cv.fit_transform(anime['tags']).toarray()
vector.shape
# Out:
# (23339, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vector)
similarity.shape
# Out:
# (23339, 23339)

# %%
anime[anime['title'] == 'Jujutsu Kaisen'].index[0]
# Out:
# 73

# %%
def content_recommendation(anime_title):
    index = anime[anime['title'] == anime_title].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])

    print("Content-Based Recommendation \n")
    for i, (anime_index, similarity_score) in zip(range(0, 10), distances[1:11]):
        recommended_anime_title = anime.iloc[anime_index].title
        print(f"{i+1}. {recommended_anime_title}")

# %%
content_recommendation('Fullmetal Alchemist: Brotherhood')
# Out:
# Content-Based Recommendation
#
# 1. Fullmetal Alchemist
# 2. Fullmetal Alchemist: The Conqueror of Shamballa
# 3. Fullmetal Alchemist: The Sacred Star of Milos
# 4. Fullmetal Alchemist: The Sacred Star of Milos Specials
# 5. Fullmetal Alchemist: Brotherhood Specials
# 6. Fullmetal Alchemist: Premium Collection
# 7. Kidou Senshi Gundam SEED MSV Astray
# 8. Inferious Wakusei Senshi Gaiden Condition Green
# 9. Fullmetal Alchemist: Reflections
# 10. Houseki no Kuni

# %%
new=original_df.copy()
new.head(5)
# Out:
#                                         title episodes           status  \
# 0            Fullmetal Alchemist: Brotherhood       64  Finished Airing
# 1                                 Steins;Gate       24  Finished Airing
# 2                   Bleach: Sennen Kessen-hen       13  Finished Airing
# 3                                    Gintama°       51  Finished Airing
# 4  Kaguya-sama wa Kokurasetai: Ultra Romantic       13  Finished Airing
#
#       theme demographic                           genres type favorites  \
# 0  Military     Shounen  Action,Adventure,Drama,Fantasy,   TV   218,277
# 1   Unknown     Unknown           Drama,Sci-Fi,Suspense,   TV   183,596
# 2   Unknown     Shounen        Action,Adventure,Fantasy,   TV    18,421
# 3   Unknown     Shounen            Action,Comedy,Sci-Fi,   TV    16,042
# 4    School      Seinen                  Comedy,Romance,   TV    29,397
#
#   popularity rank  score    members  \
# 0         #3   #1   9.10  3,190,961
# 1        #13   #2   9.07  2,452,142
# 2       #458   #3   9.06    455,428
# 3       #332   #4   9.06    599,235
# 4       #193   #5   9.05    832,346
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Eccentric scientist Rintarou Okabe has a never...
# 2  Substitute Soul Reaper Ichigo Kurosaki spends ...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  The elite members of Shuchiin Academy's studen...
#
#                           aired         duration    premiered  \
# 0    Apr 5, 2009 to Jul 4, 2010  24 min. per ep.  Spring 2009
# 1   Apr 6, 2011 to Sep 14, 2011  24 min. per ep.  Spring 2011
# 2  Oct 11, 2022 to Dec 27, 2022  24 min. per ep.    Fall 2022
# 3   Apr 8, 2015 to Mar 30, 2016  24 min. per ep.  Spring 2015
# 4   Apr 9, 2022 to Jun 25, 2022  23 min. per ep.  Spring 2022
#
#                  studios
# 0                  Bones
# 1              White Fox
# 2                Pierrot
# 3  Bandai Namco Pictures
# 4           A-1 Pictures

# %%
from sklearn.preprocessing import MinMaxScaler

numerical_columns = ['score', 'members']

# Remove commas from numerical columns and scale using MinMaxScaler
new[numerical_columns] = new[numerical_columns].replace({',': ''}, regex=True)
scaler = MinMaxScaler()
new[numerical_columns] = scaler.fit_transform(new[numerical_columns])

anime_rating = pd.concat([new['title'],new[numerical_columns]], axis=1)

# %%
anime_rating.head(15)
# Out:
#                                                 title     score   members
# 0                    Fullmetal Alchemist: Brotherhood  1.000000  0.848175
# 1                                         Steins;Gate  0.995862  0.651793
# 2                           Bleach: Sennen Kessen-hen  0.994483  0.121054
# 3                                            Gintama°  0.994483  0.159279
# 4          Kaguya-sama wa Kokurasetai: Ultra Romantic  0.993103  0.221241
# 5                  Shingeki no Kyojin Season 3 Part 2  0.993103  0.563034
# 6   Shingeki no Kyojin: The Final Season - Kankets...  0.991724  0.119385
# 7                                            Gintama'  0.991724  0.140517
# 8                                  Gintama: The Final  0.991724  0.035739
# 9                              Hunter x Hunter (2011)  0.991724  0.710235
# 10                                Gintama': Enchousen  0.990345  0.082600
# 11                               Ginga Eiyuu Densetsu  0.988966  0.081522
# 12                           Fruits Basket: The Final  0.986207  0.115747
# 13                                           Gintama.  0.983448  0.079585
# 14         Bleach: Sennen Kessen-hen - Ketsubetsu-tan  0.979310  0.034291

# %%
new_column_names = {
    'score': 'ratings_scores',
    'members': 'popularity_members'
}

anime_rating.rename(columns=new_column_names, inplace=True)
anime_rating['average_ratings']=(.85*anime_rating['ratings_scores'])+(.15*anime_rating['popularity_members'])
anime_rating.head(10)
# Out:
#                                                title  ratings_scores  \
# 0                   Fullmetal Alchemist: Brotherhood        1.000000
# 1                                        Steins;Gate        0.995862
# 2                          Bleach: Sennen Kessen-hen        0.994483
# 3                                           Gintama°        0.994483
# 4         Kaguya-sama wa Kokurasetai: Ultra Romantic        0.993103
# 5                 Shingeki no Kyojin Season 3 Part 2        0.993103
# 6  Shingeki no Kyojin: The Final Season - Kankets...        0.991724
# 7                                           Gintama'        0.991724
# 8                                 Gintama: The Final        0.991724
# 9                             Hunter x Hunter (2011)        0.991724
#
#    popularity_members  average_ratings
# 0            0.848175         0.977226
# 1            0.651793         0.944252
# 2            0.121054         0.863468
# 3            0.159279         0.869202
# 4            0.221241         0.877324
# 5            0.563034         0.928593
# 6            0.119385         0.860873
# 7            0.140517         0.864043
# 8            0.035739         0.848326
# 9            0.710235         0.949501

# %%
sorted_df = anime_rating.sort_values(by='average_ratings', ascending=False)
sorted_df.iloc[0:50]
# Out:
#                                                  title  ratings_scores  \
# 0                     Fullmetal Alchemist: Brotherhood        1.000000
# 9                               Hunter x Hunter (2011)        0.991724
# 1                                          Steins;Gate        0.995862
# 80                                          Death Note        0.933793
# 108                                 Shingeki no Kyojin        0.922759
# 5                   Shingeki no Kyojin Season 3 Part 2        0.993103
# 27                                      Kimi no Na wa.        0.965517
# 16                                      Koe no Katachi        0.977931
# 127                                      One Punch Man        0.917241
# 19                  Code Geass: Hangyaku no Lelouch R2        0.973793
# 126                                   Kimetsu no Yaiba        0.917241
# 52                     Code Geass: Hangyaku no Lelouch        0.944828
# 56                                           One Piece        0.943448
# 33                Shingeki no Kyojin: The Final Season        0.958621
# 73                                      Jujutsu Kaisen        0.935172
# 125                        Shingeki no Kyojin Season 2        0.918621
# 36                       Sen to Chihiro no Kamikakushi        0.955862
# 79                         Shingeki no Kyojin Season 3        0.933793
# 68                             Shigatsu wa Kimi no Uso        0.937931
# 41                                        Cowboy Bebop        0.951724
# 4           Kaguya-sama wa Kokurasetai: Ultra Romantic        0.993103
# 18                                Clannad: After Story        0.976552
# 32                                   Mob Psycho 100 II        0.958621
# 15                                             Gintama        0.977931
# 3                                             Gintama°        0.994483
# 61                                   Violet Evergarden        0.940690
# 34                       Kimetsu no Yaiba: Yuukaku-hen        0.957241
# 7                                             Gintama'        0.991724
# 25                                             Monster        0.968276
# 2                            Bleach: Sennen Kessen-hen        0.994483
# 42                                        Vinland Saga        0.950345
# 6    Shingeki no Kyojin: The Final Season - Kankets...        0.991724
# 37   Haikyuu!! Karasuno Koukou vs. Shiratorizawa Ga...        0.955862
# 39         Shingeki no Kyojin: The Final Season Part 2        0.954483
# 131                                     Mob Psycho 100        0.915862
# 74                          Tengen Toppa Gurren Lagann        0.935172
# 12                            Fruits Basket: The Final        0.986207
# 123                              Yakusoku no Neverland        0.918621
# 10                                 Gintama': Enchousen        0.990345
# 11                                Ginga Eiyuu Densetsu        0.988966
# 65                                       Made in Abyss        0.939310
# 76            Kimetsu no Yaiba Movie: Mugen Ressha-hen        0.933793
# 71                             Haikyuu!! Second Season        0.935172
# 63                                 Howl no Ugoku Shiro        0.939310
# 21                             Violet Evergarden Movie        0.972414
# 8                                   Gintama: The Final        0.991724
# 13                                            Gintama.        0.983448
# 153                                          Haikyuu!!        0.908966
# 60                                       Mononoke Hime        0.940690
# 82                                        Spy x Family        0.932414
#
#      popularity_members  average_ratings
# 0              0.848175         0.977226
# 9              0.710235         0.949501
# 1              0.651793         0.944252
# 80             0.991508         0.942450
# 108            1.000000         0.934345
# 5              0.563034         0.928593
# 27             0.694077         0.924801
# 16             0.586403         0.919202
# 127            0.816851         0.902183
# 19             0.453731         0.895784
# 126            0.752648         0.892552
# 52             0.574314         0.889251
# 56             0.580902         0.889066
# 33             0.494226         0.888962
# 73             0.605222         0.885680
# 125            0.685835         0.883703
# 36             0.470226         0.883017
# 79             0.591620         0.882467
# 68             0.563825         0.881815
# 41             0.473089         0.879929
# 4              0.221241         0.877324
# 18             0.306697         0.876074
# 32             0.383205         0.872308
# 15             0.272999         0.872191
# 3              0.159279         0.869202
# 61             0.448248         0.866823
# 34             0.336740         0.864166
# 7              0.140517         0.864043
# 25             0.271882         0.863817
# 2              0.121054         0.863468
# 42             0.365437         0.862609
# 6              0.119385         0.860873
# 37             0.304906         0.858219
# 39             0.304769         0.857026
# 131            0.522958         0.856926
# 74             0.412852         0.856824
# 12             0.115747         0.855638
# 123            0.498649         0.855625
# 10             0.082600         0.854183
# 11             0.081522         0.852849
# 65             0.346086         0.850327
# 76             0.376529         0.850203
# 71             0.363329         0.849396
# 63             0.335221         0.848697
# 21             0.147134         0.848622
# 8              0.035739         0.848326
# 13             0.079585         0.847869
# 153            0.499570         0.847556
# 60             0.317913         0.847273
# 82             0.363618         0.847094

# %%
def Hybrid_recommendation(anime_title):
    print("Hybrid Recommendation - ",anime_title,)
    index = anime[anime['title'] == anime_title].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    hybrid_scores = []
    similar_anime_indices = []

    param=100;
    for i, dist in distances[1:(len(distances)//param)]:
        similar_anime_title = anime.iloc[i].title
        similar_anime_row = anime_rating [anime_rating['title'] == similar_anime_title]

        if not pd.isnull(similar_anime_row['average_ratings'].values[0]):
            # Calculate the hybrid score using the given formula
            hybrid_score = dist * 0.65 + similar_anime_row['average_ratings'].values[0] * 0.35
            hybrid_scores.append((similar_anime_title, hybrid_score))
            similar_anime_indices.append(i)

    hybrid_scores.sort(key=lambda x: x[1], reverse=True)

    # Print the top 10 recommended anime with their titles and hybrid scores
    print("Top 10 Recommended Anime:\n")
    for i, (anime_title, hybrid_score) in zip(range(1, 11), hybrid_scores):
        print(f"{i}. {anime_title} - (Hybrid Score: {hybrid_score:.3f})")

# %%
Hybrid_recommendation('Chainsaw Man')
print("\n")
content_recommendation('Chainsaw Man')
# Out:
# Hybrid Recommendation -  Chainsaw Man
# Top 10 Recommended Anime:
#
# 1. Hunter x Hunter (2011) - (Hybrid Score: 0.390)
# 2. Fullmetal Alchemist: Brotherhood - (Hybrid Score: 0.389)
# 3. Devilman: Crybaby - (Hybrid Score: 0.376)
# 4. Kimi no Na wa. - (Hybrid Score: 0.372)
# 5. Jujutsu Kaisen 2nd Season - (Hybrid Score: 0.362)
# 6. Odd Taxi - (Hybrid Score: 0.351)
# 7. Hunter x Hunter - (Hybrid Score: 0.349)
# 8. Yondemasu yo, Azazel-san. (TV) - (Hybrid Score: 0.348)
# 9. Shounen Sunday CM: Devil & Devil - (Hybrid Score: 0.345)
# 10. Tokyo Ghoul - (Hybrid Score: 0.342)
#
#
# Content-Based Recommendation
#
# 1. Shounen Sunday CM: Devil & Devil
# 2. Time Slip Ichimannen: Prime Rose
# 3. Morengen
# 4. Issunboushi: Chibisuke Monogatari
# 5. Devilman: Crybaby
# 6. Yondemasu yo, Azazel-san. (TV)
# 7. Shin Megami Tensei Devil Children: Light & Dark
# 8. Chouja Raideen
# 9. Jie Mo Ren
# 10. One Piece: Adventure of Nebulandia

# %%
Hybrid_recommendation('Death Note')
print("\n")
content_recommendation('Death Note')
# Out:
# Hybrid Recommendation -  Death Note
# Top 10 Recommended Anime:
#
# 1. Death Note: Rewrite - (Hybrid Score: 0.461)
# 2. Death Parade - (Hybrid Score: 0.377)
# 3. One Piece - (Hybrid Score: 0.368)
# 4. Yadamon - (Hybrid Score: 0.363)
# 5. Soul Eater - (Hybrid Score: 0.359)
# 6. JoJo no Kimyou na Bouken Part 6: Stone Ocean Part 3 - (Hybrid Score: 0.347)
# 7. Dr. Stone - (Hybrid Score: 0.343)
# 8. No Game No Life - (Hybrid Score: 0.342)
# 9. Angel Beats! - (Hybrid Score: 0.342)
# 10. Shinigami no Ballad. - (Hybrid Score: 0.341)
#
#
# Content-Based Recommendation
#
# 1. Death Note: Rewrite
# 2. Yadamon
# 3. Shinigami no Ballad.
# 4. Ghost Messenger
# 5. Xiao Men Shen
# 6. Mahou Shoujo Lalabel
# 7. Karas
# 8. Dia Horizon (Kabu)
# 9. Kurayami Santa
# 10. Yuan Shen Haojie

# %%
Hybrid_recommendation("Vivy: Fluorite Eye's Song")
print("\n")
content_recommendation("Vivy: Fluorite Eye's Song")
# Out:
# Hybrid Recommendation -  Vivy: Fluorite Eye's Song
# Top 10 Recommended Anime:
#
# 1. "Oshi no Ko" - (Hybrid Score: 0.398)
# 2. Shingeki no Kyojin - (Hybrid Score: 0.389)
# 3. Kageki Shoujo!! - (Hybrid Score: 0.375)
# 4. Detective Conan OVA 11: A Secret Order from London - (Hybrid Score: 0.368)
# 5. Fruits Basket: The Final - (Hybrid Score: 0.353)
# 6. Carole & Tuesday - (Hybrid Score: 0.341)
# 7. Suki na Ko ga Megane wo Wasureta - (Hybrid Score: 0.336)
# 8. Wonder Egg Priority - (Hybrid Score: 0.335)
# 9. Sayonara no Asa ni Yakusoku no Hana wo Kazarou - (Hybrid Score: 0.334)
# 10. Steins;Gate 0 - (Hybrid Score: 0.332)
#
#
# Content-Based Recommendation
#
# 1. Ai City
# 2. Detective Conan OVA 11: A Secret Order from London
# 3. Fortune Dogs
# 4. Kageki Shoujo!!
# 5. Nekketsu Uchuujin
# 6. Don't Cry (Movie)
# 7. Suki na Ko ga Megane wo Wasureta
# 8. Buddy Go!
# 9. eX-Driver: Nina & Rei Danger Zone
# 10. Kamisama no Inai Nichiyoubi

# %%
Hybrid_recommendation('Dr. Stone')
print("\n")
content_recommendation('Dr. Stone')
# Out:
# Hybrid Recommendation -  Dr. Stone
# Top 10 Recommended Anime:
#
# 1. Dr. Stone: Ryuusui - (Hybrid Score: 0.564)
# 2. Dr. Stone: New World - (Hybrid Score: 0.547)
# 3. Dr. Stone: Stone Wars - (Hybrid Score: 0.507)
# 4. Sekikashita Kusanagi - (Hybrid Score: 0.436)
# 5. Death Note - (Hybrid Score: 0.386)
# 6. Tengen Toppa Gurren Lagann Movie 2: Lagann-hen - (Hybrid Score: 0.351)
# 7. Tengoku Daimakyou - (Hybrid Score: 0.335)
# 8. No Game No Life: Zero - (Hybrid Score: 0.332)
# 9. Dragon Ball Z - (Hybrid Score: 0.323)
# 10. Sayonara no Asa ni Yakusoku no Hana wo Kazarou - (Hybrid Score: 0.321)
#
#
# Content-Based Recommendation
#
# 1. Dr. Stone: Ryuusui
# 2. Dr. Stone: New World
# 3. Dr. Stone: Stone Wars
# 4. Sekikashita Kusanagi
# 5. Dr. Stone: New World Part 2
# 6. Kishin Taisen Gigantic Formula
# 7. Mirai Shounen Conan 2: Taiga Daibouken
# 8. Dr. Slump Movie 10: Arale no Bikkuriman
# 9. Choushin Hime Dangaizer 3
# 10. Groove Adventure Rave

# %%
Hybrid_recommendation('Tokyo Ghoul')
print("\n")
content_recommendation('Tokyo Ghoul')
# Out:
# Hybrid Recommendation -  Tokyo Ghoul
# Top 10 Recommended Anime:
#
# 1. Tokyo Ghoul √A - (Hybrid Score: 0.370)
# 2. Monster - (Hybrid Score: 0.363)
# 3. Chainsaw Man - (Hybrid Score: 0.354)
# 4. Yojouhan Shinwa Taikei - (Hybrid Score: 0.340)
# 5. Ookami Kodomo no Ame to Yuki - (Hybrid Score: 0.333)
# 6. Yoru wa Mijikashi Arukeyo Otome - (Hybrid Score: 0.332)
# 7. Koukaku Kidoutai: Stand Alone Complex 2nd GIG - (Hybrid Score: 0.330)
# 8. Tokyo Ghoul: "Jack" - (Hybrid Score: 0.329)
# 9. Golden Time - (Hybrid Score: 0.327)
# 10. Shinsekai yori - (Hybrid Score: 0.326)
#
#
# Content-Based Recommendation
#
# 1. Tokyo Ghoul √A
# 2. Tokyo Ghoul: "Jack"
# 3. Tokyo Ghoul:re 2nd Season
# 4. Tokyo Ghoul:re
# 5. Gift±
# 6. Baozou Kongbu Gushi
# 7. Baozou Kongbu Gushi 2nd Season
# 8. Baozou Kongbu Gushi 3rd Season
# 9. Baozou Kongbu Gushi 4th Season
# 10. Baozou Kongbu Gushi 5th Season

# %%
Hybrid_recommendation('One Punch Man')
print("\n")
content_recommendation('One Punch Man')
# Out:
# Hybrid Recommendation -  One Punch Man
# Top 10 Recommended Anime:
#
# 1. One Punch Man: Road to Hero - (Hybrid Score: 0.505)
# 2. One Punch Man 2nd Season - (Hybrid Score: 0.456)
# 3. Go! Saitama - (Hybrid Score: 0.453)
# 4. Boku no Hero Academia 6th Season - (Hybrid Score: 0.380)
# 5. One Outs - (Hybrid Score: 0.368)
# 6. One Piece - (Hybrid Score: 0.351)
# 7. Boku no Hero Academia - (Hybrid Score: 0.347)
# 8. Boku no Hero Academia 3rd Season - (Hybrid Score: 0.347)
# 9. Urawa no Usagi-chan - (Hybrid Score: 0.345)
# 10. The Four Seasons - (Hybrid Score: 0.343)
#
#
# Content-Based Recommendation
#
# 1. One Punch Man: Road to Hero
# 2. Go! Saitama
# 3. One Punch Man 2nd Season
# 4. Urawa no Usagi-chan
# 5. Kankou Taisen Saitama: Sakuya no Tatakai
# 6. The Four Seasons
# 7. Saitama-ken Zaijuu, Fujiyama Osamu, 33-sai, Mushoku (NEET).: Fujilog Nyuumon-hen Specials
# 8. Saitama-ken Zaijuu, Fujiyama Osamu, 33-sai, Mushoku (NEET).: Fujilog Nyuumon-hen
# 9. Alphard x Taka no Tsume
# 10. Kumo no Gakkou

# %%
Hybrid_recommendation('Spy x Family')
print("\n")
content_recommendation('Spy x Family')
# Out:
# Hybrid Recommendation -  Spy x Family
# Top 10 Recommended Anime:
#
# 1. Spy x Family Part 2 - (Hybrid Score: 0.449)
# 2. Boku no Hero Academia 2nd Season - (Hybrid Score: 0.353)
# 3. Yakusoku no Neverland - (Hybrid Score: 0.350)
# 4. Ookami Kodomo no Ame to Yuki - (Hybrid Score: 0.347)
# 5. Boku no Hero Academia 3rd Season - (Hybrid Score: 0.334)
# 6. Koukaku Kidoutai - (Hybrid Score: 0.325)
# 7. Bartender - (Hybrid Score: 0.320)
# 8. Tokyo Godfathers - (Hybrid Score: 0.318)
# 9. Toaru Kagaku no Railgun T - (Hybrid Score: 0.316)
# 10. Aria the Crepuscolo - (Hybrid Score: 0.315)
#
#
# Content-Based Recommendation
#
# 1. Spy x Family Part 2
# 2. Spy x Family Season 2
# 3. Eden (ONA)
# 4. Bartender
# 5. Bartender: Kami no Glass
# 6. EDEN
# 7. Akanesasu Shoujo
# 8. Freedom
# 9. Twilight (#1 Abstract na Ringo-tachi)
# 10. Spy x Family Movie: Code: White

# %%
Hybrid_recommendation('86')
print("\n")
content_recommendation('86')
# Out:
# Hybrid Recommendation -  86
# Top 10 Recommended Anime:
#
# 1. 86 Part 2 - (Hybrid Score: 0.526)
# 2. Shingeki no Kyojin - (Hybrid Score: 0.371)
# 3. Shingeki no Kyojin: The Final Season - (Hybrid Score: 0.367)
# 4. Ginga Eiyuu Densetsu - (Hybrid Score: 0.362)
# 5. Code Geass: Hangyaku no Lelouch - (Hybrid Score: 0.355)
# 6. Shingeki no Kyojin Season 2 - (Hybrid Score: 0.354)
# 7. Youjo Senki Movie - (Hybrid Score: 0.350)
# 8. Drifters - (Hybrid Score: 0.326)
# 9. Schwarzesmarken - (Hybrid Score: 0.326)
# 10. Youjo Senki - (Hybrid Score: 0.325)
#
#
# Content-Based Recommendation
#
# 1. 86 Part 2
# 2. Schwarzesmarken
# 3. Terra Formars: Revenge
# 4. 86 Special Edition: Senya ni Akaku Hinageshi no Saku
# 5. Rainbow Sentai Robin
# 6. Brave Witches
# 7. Senjuushi
# 8. Malay Oki Kaisen
# 9. Psychoarmor Govarian
# 10. Aldnoah.Zero

# %%
anime_list = ['"Oshi no Ko"',"Charlotte","Jujutsu Kaisen" ]

# %%
for anime_title in anime_list:
    # Check if the anime title exists
    if anime[anime['title'] == anime_title].empty:
        print(f"{anime_title} not found in the anime dataset.\n")
    else:
        print(f"Recommendations for {anime_title}:\n")
        Hybrid_recommendation(anime_title)
        print("\n")
        content_recommendation(anime_title)
        print("\n" + "="*50 + "\n")
# Out:
# Recommendations for "Oshi no Ko":
#
# Hybrid Recommendation -  "Oshi no Ko"
# Top 10 Recommended Anime:
#
# 1. Kageki Shoujo!! - (Hybrid Score: 0.416)
# 2. Idol - (Hybrid Score: 0.398)
# 3. Perfect Blue - (Hybrid Score: 0.384)
# 4. Vivy: Fluorite Eye's Song - (Hybrid Score: 0.378)
# 5. Detective Conan OVA 11: A Secret Order from London - (Hybrid Score: 0.377)
# 6. Suki na Ko ga Megane wo Wasureta - (Hybrid Score: 0.359)
# 7. IDOLiSH7 Second Beat! - (Hybrid Score: 0.359)
# 8. Wonder Egg Priority - (Hybrid Score: 0.357)
# 9. Jigoku Shoujo Futakomori - (Hybrid Score: 0.352)
# 10. Oshi ga Budoukan Ittekuretara Shinu - (Hybrid Score: 0.352)
#
#
# Content-Based Recommendation
#
# 1. Kageki Shoujo!!
# 2. Detective Conan OVA 11: A Secret Order from London
# 3. Ai City
# 4. Buddy Go!
# 5. Fortune Dogs
# 6. Suki na Ko ga Megane wo Wasureta
# 7. Wake Up, Girls! Shin Shou
# 8. Jigoku Shoujo: Yoi no Togi
# 9. Oshi ga Budoukan Ittekuretara Shinu
# 10. 8-gatsu no Symphony: Shibuya 2002-2003
#
# ==================================================
#
# Recommendations for Charlotte:
#
# Hybrid Recommendation -  Charlotte
# Top 10 Recommended Anime:
#
# 1. Kaguya-sama wa Kokurasetai: Ultra Romantic - (Hybrid Score: 0.520)
# 2. Seitokai Yakuindomo Movie - (Hybrid Score: 0.472)
# 3. Gakuen Utopia Manabi Straight! - (Hybrid Score: 0.467)
# 4. Kaguya-sama wa Kokurasetai: Ultra Romantic Teaser PV - Ishigami Yuu wa Kataritai - (Hybrid Score: 0.466)
# 5. Seitokai Yakuindomo - (Hybrid Score: 0.453)
# 6. Kaguya-sama wa Kokurasetai? Tensai-tachi no Renai Zunousen - (Hybrid Score: 0.452)
# 7. Kaguya-sama wa Kokurasetai? Tensai-tachi no Renai Zunousen OVA - (Hybrid Score: 0.440)
# 8. Yagate Kimi ni Naru - (Hybrid Score: 0.440)
# 9. Seitokai no Ichizon - (Hybrid Score: 0.422)
# 10. Gokujou Seitokai - (Hybrid Score: 0.409)
#
#
# Content-Based Recommendation
#
# 1. Gakuen Utopia Manabi Straight!
# 2. Himegoto
# 3. Seitokai Yakuindomo Movie
# 4. Kaguya-sama wa Kokurasetai: Ultra Romantic
# 5. Seitokai Yakuindomo
# 6. Kaguya-sama wa Kokurasetai: Ultra Romantic Teaser PV - Ishigami Yuu wa Kataritai
# 7. Kaguya-sama wa Kokurasetai? Tensai-tachi no Renai Zunousen OVA
# 8. Gokujou Seitokai
# 9. Kame no Koura wa Abarabone
# 10. Blue Archive the Animation
#
# ==================================================
#
# Recommendations for Jujutsu Kaisen:
#
# Hybrid Recommendation -  Jujutsu Kaisen
# Top 10 Recommended Anime:
#
# 1. Grisaia no Rakuen - (Hybrid Score: 0.432)
# 2. Jujutsu Kaisen Official PV - (Hybrid Score: 0.409)
# 3. Grisaia no Meikyuu: Caprice no Mayu 0 - (Hybrid Score: 0.396)
# 4. Jujutsu Kaisen 2nd Season - (Hybrid Score: 0.394)
# 5. Grisaia no Kajitsu - (Hybrid Score: 0.372)
# 6. Jujutsu Kaisen 0 Movie - (Hybrid Score: 0.368)
# 7. Shakugan no Shana II (Second) - (Hybrid Score: 0.365)
# 8. Shakugan no Shana Movie - (Hybrid Score: 0.364)
# 9. Kimetsu no Yaiba - (Hybrid Score: 0.362)
# 10. Code Geass: Hangyaku no Lelouch - (Hybrid Score: 0.362)
#
#
# Content-Based Recommendation
#
# 1. Grisaia no Rakuen
# 2. Jujutsu Kaisen Official PV
# 3. Grisaia no Meikyuu: Caprice no Mayu 0
# 4. Tonagura!
# 5. Shakugan no Shana Movie
# 6. Tensei Kenja no Isekai Life: Dai-2 no Shokugyou wo Ete, Sekai Saikyou ni Narimashita
# 7. Grisaia no Kajitsu
# 8. Shakugan no Shana II (Second)
# 9. Choujin Sentai Baratack
# 10. Jujutsu Kaisen 2nd Season
#
# ==================================================
